# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DE_plot.csv")

df.head()
# Out:
#               CN         SRV_CN         CTY_CN  PREV_PLT_CN  INVYR  STATECD  \
# 0  9187278010661  9187277010661  1320304010538          NaN   1986       10
# 1  9187313010661  9187277010661  1320304010538          NaN   1986       10
# 2  9187346010661  9187277010661  1320304010538          NaN   1986       10
# 3  9187385010661  9187277010661  1320304010538          NaN   1986       10
# 4  9187421010661  9187277010661  1320304010538          NaN   1986       10
#
#    UNITCD  COUNTYCD  PLOT  PLOT_STATUS_CD  ...  MANUAL_RMRS  PAC_ISLAND_PNWRS  \
# 0       1         1     1               1  ...          NaN               NaN
# 1       1         1     2               1  ...          NaN               NaN
# 2       1         1     3               1  ...          NaN               NaN
# 3       1         1     4               1  ...          NaN               NaN
# 4       1         1     5               1  ...          NaN               NaN
#
# ...
